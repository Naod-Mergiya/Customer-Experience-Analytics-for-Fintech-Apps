# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import time
import os
import sys
import spacy
from transformers import pipeline
from collections import defaultdict
from script.scrape_bank_review import *
from script.clean_review import *
#from script.analysis_utils import process_reviews, aggregate_sentiment, aggregate_themes, save_results
# Add the parent directory () to the Python path
# Add the root directory (parent of benin_eda_project/ and script/) to the Python path
root_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(root_dir)
print(f"Added {root_dir} to sys.path")

try:
    from script.scrape_bank_review import scrape_all_banks, scrape_bank_reviews
    print("Import successful.")
except ImportError as e:
    print(f"Import error: {e}")
    raise

print("Modules imported successfully.")
# Out:
# Added e:\KAIM to sys.path
# Import successful.
# Modules imported successfully.

# %% [markdown]
# ##### bank apps

# %%
# Define the banks with their app IDs
banks = [
    {"name": "BOA", "app_id": "com.boa.boaMobileBanking"},
    {"name": "CBE", "app_id": "com.combanketh.mobilebanking"},
    {"name": "Dashen", "app_id": "com.dashen.dashensuperapp"}
]

# %%
# Scrape reviews and create DataFrames for each bank
df_CBE = None
df_BOA = None
df_Dashen = None

# %%
for bank in banks:
    bank_playstore_id = bank["app_id"]
    print(f"\nFetching reviews for {bank['name']} (ID: {bank_playstore_id})...\n")
    try:
        result, continuation_token = reviews(
            bank_playstore_id,
            lang="en",
            country="et",  # Ethiopia
            sort=Sort.NEWEST,
            count=400,  # Reduced to avoid rate limits
            filter_score_with=None
        )
        if not result:
            print(f"No reviews found for {bank['name']}.")
            continue

        # Format reviews for DataFrame
        reviews_data = [
            {
                "user_name": review.get('userName', ''),
                "rating": review.get('score', ''),
                "date": review.get('at').strftime('%Y-%m-%d %H:%M:%S') if review.get('at') else 'N/A',
                "review": review.get('content', ''),
                "review_id": review.get('reviewId', ''),
                "app_version": review.get('appVersion', ''),
                "replied_at": str(review.get('repliedAt', '—')),
                "reply_content": review.get('replyContent', '—'),
                "thumbs_up_count": review.get('thumbsUpCount', ''),
                "user_image_url": review.get('userImage', ''),
                "bank": bank["name"],
                "source": "Google Play"
            }
            for review in result
        ]

        # Create DataFrame for this bank's reviews
        df = pd.DataFrame(reviews_data)

        # Assign to the appropriate DataFrame variable
        if bank["name"] == "BOA":
            df_BOA = df
        elif bank["name"] == "CBE":
            df_CBE = df
        elif bank["name"] == "Dashen":
            df_Dashen = df

        # Print reviews for verification
        for i, review in enumerate(result, 1):
            print(f":small_blue_diamond: Review {i}")
            print(f"  :adult: User Name        : {review.get('userName', '')}")
            print(f"  :star: Rating           : {review.get('score', '')}")
            print(
                f"  :date: Date            : {review.get('at').strftime('%Y-%m-%d %H:%M:%S') if review.get('at') else 'N/A'}"
            )
            print(f"  :memo: Review Content   : {review.get('content', '')}")
            print(f"  :id: Review ID        : {review.get('reviewId', '')}")
            print(f"  :iphone: App Version      : {review.get('appVersion', '')}")
            print(f"  :repeat: Replied At       : {review.get('repliedAt', '—')}")
            print(f"  :speech_balloon: Reply Content    : {review.get('replyContent', '—')}")
            print(f"  :+1: Thumbs Up Count  : {review.get('thumbsUpCount', '')}")
            print(f"  :globe_with_meridians: User Image URL   : {review.get('userImage', '')}")
            print("-" * 70)

        # Save to CSV
        save_dir = os.path.join('..', 'data')
        os.makedirs(save_dir, exist_ok=True)
        file_path = os.path.join(save_dir, f"{bank['name']}_reviews.csv")
        df.to_csv(file_path, index=False)
        print(f"Created DataFrame df_{bank['name']} with {len(df)} reviews and saved to {file_path}")

        # Add delay to avoid rate limiting
        time.sleep(5)  # Increased delay to ensure scraper stability

    except Exception as e:
        print(f"Error fetching reviews for {bank['name']}: {e}")
        continue  # Ensure loop continues even if one bank fails

# Verify all DataFrames were created
if df_BOA is not None:
    print(f"\ndf_BOA contains {len(df_BOA)} reviews")
    print(df_BOA.head())
else:
    print("\ndf_BOA was not created")
if df_CBE is not None:
    print(f"\ndf_CBE contains {len(df_CBE)} reviews")
    print(df_CBE.head())
else:
    print("\ndf_CBE was not created")
if df_Dashen is not None:
    print(f"\ndf_Dashen contains {len(df_Dashen)} reviews")
    print(df_Dashen.head())
else:
    print("\ndf_Dashen was not created")
# Out:
# Fetching reviews for BOA (ID: com.boa.boaMobileBanking)...
#
# :small_blue_diamond: Review 1
#   :adult: User Name        : Phillmon Haftom
#   :star: Rating           : 3
#   :date: Date            : 2025-06-05 11:57:36
#   :memo: Review Content   : it's not working
#   :id: Review ID        : 937102c6-ae88-419c-994b-80e520faacb8
#   :iphone: App Version      : 25.05.03
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocJUHD1VlowMkpu5Ud6IlrkId8h-uGAlDtJtFS8bLkxHA1gDeA=mo
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 2
#   :adult: User Name        : Robel Alebachew
#   :star: Rating           : 1
#   :date: Date            : 2025-06-03 16:21:34
#   :memo: Review Content   : Hello, I’m facing a problem with the BOA Mobile app. Every time I enter my phone number and password, the app crashes and shows an error that says “BoaMobile closed because this app has a bug.” I tried updating, reinstalling, and clearing cache, but nothing worked. Please fix this bug in the next update. I really need access to my account. Thank you.
#   :id: Review ID        : 3559b91c-fad9-4032-bebe-cf99974b9628
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocKc3cWFE6DB-KelsfBZrSQ5KjVQ7TztXXm7wELqjMcFMLChYw=mo
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 3
#   :adult: User Name        : Haymanot Anberber
#   :star: Rating           : 5
#   :date: Date            : 2025-06-03 10:32:35
#   :memo: Review Content   : exceptional
#   :id: Review ID        : 10e85f30-540d-4810-ba89-85a7e004480b
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocIwmyIbpn174q-SvjF22qALayqXshfNd2A-CAp6EcVs5j7mYg=mo
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 4
#   :adult: User Name        : Mohamed Abdillahi
#   :star: Rating           : 5
#   :date: Date            : 2025-06-02 14:25:12
#   :memo: Review Content   : BoA Mobile good bank
#   :id: Review ID        : d7f07898-4ba1-47b4-9e8c-a3cc10b1bf0f
#   :iphone: App Version      : 25.05.03
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjWjpFDGs7v19_pZmUMCMtVR2F8pWgFtnQdx_Pau33zI25ducLU
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 5
#   :adult: User Name        : Ahadu tech
#   :star: Rating           : 1
#   :date: Date            : 2025-06-01 15:51:10
#   :memo: Review Content   : this is worest app 24/7 loading
#   :id: Review ID        : 2ca9480b-ff5f-4b59-952c-5921db83dab2
#   :iphone: App Version      : 25.05.03
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjWOhd6tDkB5D0Ws9KjbNiDZMM0fSVJ0ykgIWeFwpaPTgsqmNCU
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 6
#   :adult: User Name        : Fentaw Kefyalew
#   :star: Rating           : 1
#   :date: Date            : 2025-06-01 10:17:10
#   :memo: Review Content   : This App is not interest for Android phone Please update it .
#   :id: Review ID        : 8cd852da-0257-4ca0-9003-314fb464e55a
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-U
#   :iphone: App Version      : 25.05.03
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjXzkRzyW1X6Epgd9rxrEFT_pctOjzsrnQGv2bTfWm7TjFtt0WzF
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 25
#   :adult: User Name        : bogale abunu
#   :star: Rating           : 5
#   :date: Date            : 2025-05-10 12:44:44
#   :memo: Review Content   : i entered incorrect security question by mistake boa app lock pin forever, why is there no other options? ?? i contacted different branchs more then 4times but they didn't able to solve this issue .
#   :id: Review ID        : 301f6927-9395-4cda-bb77-041a36323875
#   :iphone: App Version      : 25.05.03
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 62
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjUNALB1lGxqtlz7jPNG4uUMSvz5nifHfGqRn0KvjbgpsHkaWYg1
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 26
#   :adult: User Name        : Eyuel Baharu
#   :star: Rating           : 5
#   :date: Date            : 2025-05-09 16:12:56
#   :memo: Review Content   : Best app
#   :id: Review ID        : 9a02c524-0d8d-445e-97d4-d1f451b16d43
#   :iphone: App Version      : 25.05.03
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocIr-vPKu609mPLrtuU1ocVNLUChrKczNN_eUW-oaF346bIELg=mo
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 27
#   :adult: User Name        : Abdu berHanu
#   :star: Rating           : 5
#   :date: Date            : 2025-05-07 18:34:10
#   :memo: Review Content   : liking this application good 👍
#   :id: Review ID        : 857bb685-6f7e-4db0-af37-eb2f1c1c6fd3
#   :iphone: App Version      : 25.05.03
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocJjoZv87agxo3zkbYHkpDgp5LOsmx4bjWgO6tAxzjQT0bJbBg=mo
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 28
#   :adult: User Name        : Ahmed Abdo Bedaso
#   :star: Rating           : 1
#   :date: Date            : 2025-05-06 18:06:33
#   :memo: Review Content   : This app future is good, but there is problems with apps to reset and activate it, which is difficult even to the branch staffs, and it takes too long times to active at the branch plus most of the time high expected failure of activation after process at the counter and OTP sent not work
#   :id: Review ID        : 62fa097e-3fd8-4522-a3a3-9b13f17f594d
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 2
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjVskSAmT2ssPhP_eVaTgOhXTop0J4YEM0Lw6dgqrB2sT5B2LU5u
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 29
#   :adult: User Name        : Amnuel Gashaw Aman
#   :star: Rating           : 5
#   :date: Date            : 2025-05-06 17:44:32
#   :memo: Review Content   : good
#   :id: Review ID        : e4f9ad9a-576a-4bbe-a910-812fd1b7e08a
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjURD5C_B1xdox1GnMrB4JMjk9iCQtUSaB6HSx9y6U0QhXcpLn5s
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 30
#   :adult: User Name        : Kidus Yohannes
#   :star: Rating           : 5
#   :date: Date            : 2025-05-02 21:50:25
#   :memo: Review Content   : good
#   :id: Review ID        : 586aecda-30fc-4daf-bca7-2d37573a5e4e
#   :iphone: App Version      : 25.03.07
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjV6PEEzUCeqclAbu_A3Z_NAjCbpT1y8FIsZVW9Bxnckt4a93mNI
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 31
#   :adult: User Name        : Cherie
#   :star: Rating           : 4
#   :date: Date            : 2025-04-30 11:23:56
#   :memo: Review Content   : good
#   :id: Review ID        : 0f3023a3-30af-479c-85e7-4165b2ce30c7
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocKLXWlJizJ5qtvxjKHQFhgN9yS_wEl_9siyR00CpQGc6GbihA=mo
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 32
#   :adult: User Name        : Amare Tilahun
#   :star: Rating           : 4
#   :date: Date            : 2025-04-30 10:34:17
#   :memo: Review Content   : good
#   :id: Review ID        : aa6d112e-713e-46d9-90a5-6c32c1b1d7ef
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 0
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjUrRhhiZGK-01GEvgLTdHORsbQxcTVwirAgarLLNPs1_uzRcUw
# ----------------------------------------------------------------------
# :small_blue_diamond: Review
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 3
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocKcN19KIo6GFBwWYrC-fo32vovcyweRG217PYsN2RCkUUjv8Q=mo
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 397
#   :adult: User Name        : Leul Tube
#   :star: Rating           : 4
#   :date: Date            : 2025-01-17 20:04:25
#   :memo: Review Content   : It has a Good performance but need more upgrade for more performance like when we login account not be fast balance show other thing looking good. Carry on. Thanks so much for Greatest service
#   :id: Review ID        : 40cc8813-3573-4cc3-bbba-3cd722362717
#   :iphone: App Version      : 1.0.4
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 75
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjVeC6Q5dwHaXwE9NfbJJs5tUnfnEsvhVDrgGqewZLRrKPUK-mBG
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 398
#   :adult: User Name        : Fantabil Deresse
#   :star: Rating           : 5
#   :date: Date            : 2025-01-17 12:04:57
#   :memo: Review Content   : It is a very wonderful work that has saved its time. That is why it is "Always one step ahead!"
#   :id: Review ID        : 42006315-95d0-4ccb-9a5c-a7ac1053d977
#   :iphone: App Version      : 1.0.4
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 5
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a-/ALV-UjUG29CUkj9J8x0RwPxPKUuvQscJWiCLxCE-0GgYNpz5TnOMOhQy
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 399
#   :adult: User Name        : Dawit Alemayehu
#   :star: Rating           : 5
#   :date: Date            : 2025-01-17 10:18:44
#   :memo: Review Content   : “Life-changing!” I can’t imagine going back to traditional banking after using this app. It’s so convenient.
#   :id: Review ID        : b969925e-d6eb-4620-9bb2-6a7868cc4d57
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 4
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocJjFdynpfwU__BHhS14e1jd8zU5qLErfHa78L21z_-CMUh7cEU=mo
# ----------------------------------------------------------------------
# :small_blue_diamond: Review 400
#   :adult: User Name        : Meba Abiye
#   :star: Rating           : 5
#   :date: Date            : 2025-01-17 08:04:15
#   :memo: Review Content   : Pro max
#   :id: Review ID        : 4082204a-22e9-4568-93dc-2e4f572a0a35
#   :iphone: App Version      : None
#   :repeat: Replied At       : None
#   :speech_balloon: Reply Content    : None
#   :+1: Thumbs Up Count  : 7
#   :globe_with_meridians: User Image URL   : https://play-lh.googleusercontent.com/a/ACg8ocLscTd0Y9yRQw0eJ3GgMGeG7w9o4UisGXwY2wdA3-jPqrru6w=mo
# ----------------------------------------------------------------------
# Created DataFrame df_Dashen with 400 reviews and saved to ..\data\Dashen_reviews.csv
#
# df_BOA contains 400 reviews
#            user_name  rating                 date  \
# 0    Phillmon Haftom       3  2025-06-05 11:57:36
# 1    Robel Alebachew       1  2025-06-03 16:21:34
# 2  Haymanot Anberber       5  2025-06-03 10:32:35
# 3  Mohamed Abdillahi       5  2025-06-02 14:25:12
# 4         Ahadu tech       1  2025-06-01 15:51:10
#
#                                               review  \
# 0                                   it's not working
# 1  Hello, I’m facing a problem with the BOA Mobil...
# 2                                        exceptional
# 3                               BoA Mobile good bank
# 4                    this is worest app 24/7 loading
#
#                               review_id app_version replied_at reply_content  \
# 0  937102c6-ae88-419c-994b-80e520faacb8    25.05.03       None          None
# 1  3559b91c-fad9-4032-bebe-cf99974b9628        None       None          None
# 2  10e85f30-540d-4810-ba89-85a7e004480b        None       None          None
# 3  d7f07898-4ba1-47b4-9e8c-a3cc10b1bf0f    25.05.03       None          None
# 4  2ca9480b-ff5f-4b59-952c-5921db83dab2    25.05.03       None          None
#
#    thumbs_up_count                                     user_image_url bank  \
# 0                0  https://play-lh.googleusercontent.com/a/ACg8oc...  BOA
# 1                0  https://play-lh.googleusercontent.com/a/ACg8oc...  BOA
# 2                0  https://play-lh.googleusercontent.com/a/ACg8oc...  BOA
# 3                0  https://play-lh.googleusercontent.com/a-/ALV-U...  BOA
# 4                0  https://play-lh.googleusercontent.com/a-/ALV-U...  BOA
#
#         source
# 0  Google Play
# 1  Google Play
# 2  Google Play
# 3  Google Play
# 4  Google Play
#
# df_CBE contains 400 reviews
#         user_name  rating                 date  \
# 0  zelalem fekadu       4  2025-06-07 20:21:52
# 1      Mossa Yiha       4  2025-06-07 18:21:26
# 2   Hussein Seifu       5  2025-06-07 11:02:38
# 3        Adonijah       2  2025-06-07 10:50:29
# 4     Aim4 Beyond       4  2025-06-06 09:54:11
#
#                                               review  \
# 0  A great app. It's like carrying a bank in your...
# 1                      More than garrantty bank EBC.
# 2  really am happy to this app it is Siple to use...
# 3  I liked this app. But the User interface is ve...
# 4  "Why don’t your ATMs support account-to-accoun...
#
#                               review_id app_version replied_at reply_content  \
# 0  a7d1c799-ba53-4a0a-a8d6-c5400a009825       5.1.0       None          None
# 1  64ed5562-1758-4eb8-9291-8b6edc394118        None       None          None
# 2  d0c05687-ddd4-43fb-95a9-08f6358d80a2       5.1.0       None          None
# 3  811bf820-3529-433a-9b6d-e624fa23a16a       5.1.0       None          None
# 4  be2cb2ac-bbe0-4175-81c4-9f6c86afdaaa        None       None          None
#
#    thumbs_up_count                                     user_image_url bank  \
# 0                0  https://play-lh.googleusercontent.com/a/ACg8oc...  CBE
# 1                0  https://play-lh.googleusercontent.com/a/ACg8oc...  CBE
# 2                0  https://play-lh.googleusercontent.com/a-/ALV-U...  CBE
# 3                0  https://play-lh.googleusercontent.com/a-/ALV-U...  CBE
# 4                0  https://play-lh.googleusercontent.com/a/ACg8oc...  CBE
#
#         source
# 0  Google Play
# 1  Google Play
# 2  Google Play
# 3  Google Play
# 4  Google Play
#
# df_Dashen contains 400 reviews
#             user_name  rating                 date  \
# 0            Adonijah       2  2025-06-07 10:40:29
# 1             OBSA KA       3  2025-06-06 00:15:44
# 2            Masersha       5  2025-06-03 19:40:31
# 3       Koki Mulugeta       5  2025-06-03 17:30:11
# 4  Badhasa Dassaalany       5  2025-06-01 17:10:53
#
#                                               review  \
# 0  I like this mobile banking app very much. Over...
# 1                                               love
# 2                                               መቸሸጠ
# 3                                                wow
# 4                                              gadaa
#
#                               review_id app_version replied_at reply_content  \
# 0  6ab16d21-d2c8-4235-9c48-ff713bfde731      1.0.16       None          None
# 1  22818807-3368-446c-8a3b-d3ca2e07a2d8      1.0.16       None          None
# 2  6ece1f5e-55f2-404d-b980-1cb45823180f      1.0.16       None          None
# 3  765ff69f-5274-45c5-985b-81b8d01e1874        None       None          None
# 4  7db66b6a-a044-43f1-a7ad-ea8a10815548      1.0.16       None          None
#
#    thumbs_up_count                                     user_image_url    bank  \
# 0                0  https://play-lh.googleusercontent.com/a-/ALV-U...  Dashen
# 1                0  https://play-lh.googleusercontent.com/a-/ALV-U...  Dashen
# 2                0  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen
# 3                0  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen
# 4                0  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen
#
#         source
# 0  Google Play
# 1  Google Play
# 2  Google Play
# 3  Google Play
# 4  Google Play

# %% [markdown]
# ##### Create index for pre processing

# %%
df["review_id"] = df.index
df.tail()
# Out:
#             user_name  rating       date  \
# 395    Mahilet Eshetu       5 2025-01-17
# 396         Leul Tube       4 2025-01-17
# 397  Fantabil Deresse       5 2025-01-17
# 398   Dawit Alemayehu       5 2025-01-17
# 399        Meba Abiye       5 2025-01-17
#
#                                                 review  review_id app_version  \
# 395           Dashen yichalal. Ewnetem one step a head        395       1.0.1
# 396  It has a Good performance but need more upgrad...        396       1.0.4
# 397  It is a very wonderful work that has saved its...        397       1.0.4
# 398  “Life-changing!” I can’t imagine going back to...        398        None
# 399                                            Pro max        399        None
#
#     replied_at reply_content  thumbs_up_count  \
# 395       None          None                3
# 396       None          None               75
# 397       None          None                5
# 398       None          None                4
# 399       None          None                7
#
#                                         user_image_url    bank       source
# 395  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen  Google Play
# 396  https://play-lh.googleusercontent.com/a-/ALV-U...  Dashen  Google Play
# 397  https://play-lh.googleusercontent.com/a-/ALV-U...  Dashen  Google Play
# 398  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen  Google Play
# 399  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen  Google Play

# %% [markdown]
# ### Preprocessing

# %%
clean_and_process_data(df)

# %%
combined_df = df
combined_df.shape
combined_df.tail()
# Out:
#             user_name  rating       date  \
# 395    Mahilet Eshetu       5 2025-01-17
# 396         Leul Tube       4 2025-01-17
# 397  Fantabil Deresse       5 2025-01-17
# 398   Dawit Alemayehu       5 2025-01-17
# 399        Meba Abiye       5 2025-01-17
#
#                                                 review  review_id app_version  \
# 395           Dashen yichalal. Ewnetem one step a head        395       1.0.1
# 396  It has a Good performance but need more upgrad...        396       1.0.4
# 397  It is a very wonderful work that has saved its...        397       1.0.4
# 398  “Life-changing!” I can’t imagine going back to...        398        None
# 399                                            Pro max        399        None
#
#     replied_at reply_content  thumbs_up_count  \
# 395       None          None                3
# 396       None          None               75
# 397       None          None                5
# 398       None          None                4
# 399       None          None                7
#
#                                         user_image_url    bank       source
# 395  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen  Google Play
# 396  https://play-lh.googleusercontent.com/a-/ALV-U...  Dashen  Google Play
# 397  https://play-lh.googleusercontent.com/a-/ALV-U...  Dashen  Google Play
# 398  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen  Google Play
# 399  https://play-lh.googleusercontent.com/a/ACg8oc...  Dashen  Google Play

# %% [markdown]
# #### Clean Data for the sentiment analysis

# %%
df_banks = combined_df.drop(columns=["user_image_url", "thumbs_up_count", "app_version", "replied_at", "reply_content"])
df_banks = df_banks.rename(columns={"review_content": "review", "rating": "rating", "date": "date"})
df_banks.head()
# Out:
#             user_name  rating       date  \
# 0            Adonijah       2 2025-06-07
# 1             OBSA KA       3 2025-06-06
# 2            Masersha       5 2025-06-03
# 3       Koki Mulugeta       5 2025-06-03
# 4  Badhasa Dassaalany       5 2025-06-01
#
#                                               review  review_id    bank  \
# 0  I like this mobile banking app very much. Over...          0  Dashen
# 1                                               love          1  Dashen
# 2                                               መቸሸጠ          2  Dashen
# 3                                                wow          3  Dashen
# 4                                              gadaa          4  Dashen
#
#         source
# 0  Google Play
# 1  Google Play
# 2  Google Play
# 3  Google Play
# 4  Google Play

# %%
clean_file = os.path.abspath(os.path.join(os.getcwd(), '..', 'data', 'clean_reviews.csv'))
sys.path.append(root_dir)
df_banks.to_csv(clean_file, index=False, encoding="utf-8")
print(f"Saved clean dataset to {clean_file}")
# Out:
# Saved clean dataset to e:\KAIM\Customer-Experience-Analytics-for-Fintech-Apps\data\clean_reviews.csv

# %% [markdown]
# Clean the data to the best format for further sentiment analysis
